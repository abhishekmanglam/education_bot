# %%
pip install --upgrade pip

pip install \
  streamlit==1.45.1 \
  langchain==0.3.25 \
  langchain-community==0.3.23 \
  langchain-core==0.3.59 \
  langchain-text-splitters==0.3.8 \
  langchain-huggingface==0.1.2 \
  langchain-groq==0.3.2 \
  sentence-transformers==3.4.1 \
  chromadb==0.5.23 \
  pypdf==5.4.0 \
  pdfplumber==0.11.6 \
  protobuf==3.20.3 \
  transformers==4.51.3 \
  torch==2.6.0

# %%
import os
path = r'C:\Users\abhis\OneDrive\Documents\GitHub\education_bot\faiss_db'
os.makedirs(path, exist_ok=True)
with open(os.path.join(path, 'test.txt'), 'w') as f:
    f.write('test')
print('Write successful:', os.path.exists(os.path.join(path, 'test.txt')))
# Out:
# Write successful: True
